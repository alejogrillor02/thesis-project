# %% [markdown]
# ### Find Project Path

# %%
import os
from pathlib import Path

# Get the script directory (using notebook path)
SCRDIR = Path(__file__).parent.resolve()

# Change to script directory
try:
	os.chdir(SCRDIR)
except Exception as e:
	print(f"Error changing to script directory: {e}")
	exit(1)

# Find project root by looking for config.yaml
PROJECTDIR = SCRDIR
found = False
while str(PROJECTDIR) != '/' and not found:
	if (PROJECTDIR / 'config.yaml').exists():
		found = True
	else:
		PROJECTDIR = PROJECTDIR.parent

# Verify config.yaml was found
if not found:
	print("Error: config.yaml not found in project root!", file=sys.stderr)
else:
	# Change to project directory
	try:
		os.chdir(PROJECTDIR)
		print(f"Changed to project directory: {PROJECTDIR}")
	except Exception as e:
		print(f"Error changing to project directory: {e}")
# Out:
# /home/hope/Documents/Thesis/project

# %% [markdown]
# ### 1. Preprocessing

# %%
# !bash ./src/data/batch_preprocessing.sh
# Out:
# bash: ./src/data/batch_preprocessing.sh: No such file or directory
# /home/hope/Documents/Thesis/project/notebooks

# %% [markdown]
# ### 2. Training

# %%
# !bash ./src/train/batch_training.sh

# %%
# @title 5. Evaluate

# !bash ./src/eval/batch_eval.sh
# Out:
# 2025-06-01 20:36:25.146170: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748810185.165611  113032 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748810185.171511  113032 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-01 20:36:25.190967: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# @title 6. SHAP Values

# !bash ./src/tests/batch_shap.sh
# Out:
# 2025-05-30 14:27:07.274437: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748615227.297618   15964 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748615227.304487   15964 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-30 14:27:07.336557: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
